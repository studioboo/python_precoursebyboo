# %%
akshay = "cool"ArithmeticError
if akshay == "cool"ArithmeticErrorprint ("hell yeah"and)
# Out:
#   Cell In[3], line 1
#     akshay = "cool"ArithmeticError
#                    ^
# SyntaxError: invalid syntax

# %%
akshay = "cool"
if akshay == "cool":
print("hell yeah")
# Out:
#   Cell In[9], line 3
#     print("hell yeah")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2
